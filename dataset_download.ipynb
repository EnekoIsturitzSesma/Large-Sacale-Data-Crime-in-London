# %%
import requests
import os

url = "https://policeuk-data.s3.amazonaws.com/download/71c81e136687db600faebbe24af346744e4d3108.zip"

script_dir = os.getcwd()

zip_path = os.path.join(
    script_dir,
    "71c81e136687db600faebbe24af346744e4d3108.zip"
)

response = requests.get(url, stream=True)
response.raise_for_status()

with open(zip_path, "wb") as f:
    for chunk in response.iter_content(chunk_size=8192):
        if chunk:
            f.write(chunk)

print(f"Archivo descargado en: {zip_path}")
# Out:
# Archivo descargado en: /home/alumno/Desktop/datos/Large Scale Data Analytics/71c81e136687db600faebbe24af346744e4d3108.zip
